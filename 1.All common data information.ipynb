# %%
import pandas as pd
import numpy as np
from google.colab import drive

# %% [markdown]
# # Load dataset

# %%
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##1. us-shein-appliances-3987.csv

# %%
pd.set_option("display.max_columns", None,"display.max_colwidth",None)

# %%
appliances = pd.read_csv("/content/drive/MyDrive/Data Science/3. Dirty E-Commerce Data [80,000+ Products]/data/us-shein-appliances-3987.csv")

# %%
appliances
# Out:
#                                                                                                                                                                    goods-title-link--jump  \
# 0                              1pc Rechargeable Deep Tissue Muscle Handheld Massage Gun, Suitable For Body, Back And Neck Pain, Ultra-Compact Elegant Design, High-Torque Driven Massager
# 1                                                                                                                                                           1pc Portable Hanging Neck Fan
# 2                                                                                          1pc Pink Colored Curved Eyelash Curler False Eyelash Auxiliary Makeup Tool For Women, Portable
# 3                                                                                         1 Mini Portable Handheld Fan With 2 Aa Batteries (Batteries Not Included), Comes With A Lanyard
# ...

# %%
appliances.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3986 entries, 0 to 3985
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   goods-title-link--jump       40 non-null     object
#  1   goods-title-link--jump href  40 non-null     object
#  2   rank-title                   559 non-null    object
#  3   rank-sub                     559 non-null    object
#  4   price                        3986 non-null   object
#  5   discount                     2459 non-null   object
#  6   selling_proposition          1361 non-null   object
#  7   goods-title-link             3946 non-null   object
# dtypes: object(8)
# memory usage: 249.2+ KB

# %%
appliances.columns
# Out:
# Index(['goods-title-link--jump', 'goods-title-link--jump href', 'rank-title',
#        'rank-sub', 'price', 'discount', 'selling_proposition',
#        'goods-title-link'],
#       dtype='object')

# %% [markdown]
# ##2. us-shein-automotive-4110.csv

# %%
automotive = pd.read_csv("/content/drive/MyDrive/Data Science/3. Dirty E-Commerce Data [80,000+ Products]/data/us-shein-automotive-4110.csv")

# %%
automotive
# Out:
#                                                                                                                                                                                                                                                          goods-title-link--jump  \
# 0     1pc/2PCS Car Cup Coaster, Bling Cup Holder Insert Coasters,Universal Auto Non-Slip Cup Holder Embedded In Ornaments Silicone Coaster, Car Interior Accessories Mat,7cm/2.75 Inch Soft Crystal Rhinestone Rubber Pad Set Round Auto Drink Coaster Car Interior Accessories
# 1                                                                                                                                                                                                                Jesus The Way Truth Life Sticker For Car Window Decor Stickers
# ...

# %%
automotive.columns
# Out:
# Index(['goods-title-link--jump', 'goods-title-link--jump href', 'price',
#        'discount', 'selling_proposition', 'goods-title-link'],
#       dtype='object')

# %%
automotive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4109 entries, 0 to 4108
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   goods-title-link--jump       40 non-null     object
#  1   goods-title-link--jump href  40 non-null     object
#  2   price                        4109 non-null   object
#  3   discount                     1373 non-null   object
#  4   selling_proposition          2874 non-null   object
#  5   goods-title-link             4069 non-null   object
# dtypes: object(6)
# memory usage: 192.7+ KB

# %% [markdown]
# ##3. us-shein-baby_and_maternity-4433.csv

# %%
baby_and_maternity = pd.read_csv("/content/drive/MyDrive/Data Science/3. Dirty E-Commerce Data [80,000+ Products]/data/us-shein-baby_and_maternity-4433.csv")

# %%
baby_and_maternity
# Out:
#                                                                                      goods-title-link--jump  \
# 0                  Baby Boys' Dinosaur Printed Vest And Letter Printed Shorts, 2pcs Casual Cute Set, Summer
# 1                                                         Baby Boy 3D Ear Design Hooded Belted Flannel Robe
# 2                                                                         Baby Girl Floral Print Cami Dress
# 3     Baby Girl's Casual And Simple Flower Printed Short Sleeve T-Shirt And Shorts Set, Suitable For Summer
# 4                                                   Baby Girl Letter Graphic Tie Dye Hoodie With Sweatpants
# ...                                                                                                     ...
# 4427                                                                                                    NaN
# 4428                                                                                                    NaN
# ...

# %%
baby_and_maternity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4432 entries, 0 to 4431
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   goods-title-link--jump       38 non-null     object
#  1   goods-title-link--jump href  38 non-null     object
#  2   selling_proposition          3501 non-null   object
#  3   price                        4432 non-null   object
#  4   discount                     2799 non-null   object
#  5   color-count                  1091 non-null   float64
#  6   goods-title-link             4394 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 242.5+ KB

# %%
baby_and_maternity.columns
# Out:
# Index(['goods-title-link--jump', 'goods-title-link--jump href',
#        'selling_proposition', 'price', 'discount', 'color-count',
#        'goods-title-link'],
#       dtype='object')

# %% [markdown]
# ##4. us-shein-bags_and_luggage-4299.csv

# %%
bags_and_luggage = pd.read_csv("/content/drive/MyDrive/Data Science/3. Dirty E-Commerce Data [80,000+ Products]/data/us-shein-bags_and_luggage-4299.csv")

# %%
bags_and_luggage
# Out:
#       color-count  \
# 0            28.0
# 1             NaN
# 2            13.0
# 3            10.0
# 4             9.0
# ...           ...
# 4293          NaN
# 4294          NaN
# 4295          NaN
# 4296          8.0
# 4297          NaN
#
#                                                                                                                                                                                              goods-title-link--jump  \
# 0                                                                                                                                                                    Mini Chevron Metal Decor Square Bag Minimalist
# 1                                                                                                  20/24/28/30 Inch Luggage Cover Bag, PVC Clear Plastic Suitcase Cover Protectors, Travel Luggage Sleeve Protector
# ...

# %%
bags_and_luggage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4298 entries, 0 to 4297
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   color-count                  1792 non-null   float64
#  1   goods-title-link--jump       39 non-null     object
#  2   goods-title-link--jump href  39 non-null     object
#  3   selling_proposition          3652 non-null   object
#  4   price                        4298 non-null   object
#  5   discount                     4153 non-null   object
#  6   rank-title                   405 non-null    object
#  7   rank-sub                     405 non-null    object
#  8   goods-title-link             4259 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 302.3+ KB

# %%
bags_and_luggage.columns
# Out:
# Index(['color-count', 'goods-title-link--jump', 'goods-title-link--jump href',
#        'selling_proposition', 'price', 'discount', 'rank-title', 'rank-sub',
#        'goods-title-link'],
#       dtype='object')

# %% [markdown]
# ##5. us-shein-beauty_and_health-4267.csv

# %%
beauty_and_health = pd.read_csv("/content/drive/MyDrive/Data Science/3. Dirty E-Commerce Data [80,000+ Products]/data/us-shein-beauty_and_health-4267.csv")

# %%
beauty_and_health
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         goods-title-link--jump  \
# ...

# %%
beauty_and_health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4266 entries, 0 to 4265
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   goods-title-link--jump       39 non-null     object
#  1   goods-title-link--jump href  39 non-null     object
#  2   selling_proposition          3257 non-null   object
#  3   price                        4266 non-null   object
#  4   discount                     3984 non-null   object
#  5   color-count                  1206 non-null   float64
#  6   rank-title                   838 non-null    object
#  7   rank-sub                     838 non-null    object
#  8   goods-title-link             4227 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 300.1+ KB

# %%
beauty_and_health.columns
# Out:
# Index(['goods-title-link--jump', 'goods-title-link--jump href',
#        'selling_proposition', 'price', 'discount', 'color-count', 'rank-title',
#        'rank-sub', 'goods-title-link'],
#       dtype='object')

# %% [markdown]
# ##6. us-shein-curve-2849.csv

# %%
curve = pd.read_csv("/content/drive/MyDrive/Data Science/3. Dirty E-Commerce Data [80,000+ Products]/data/us-shein-curve-2849.csv")

# %%
curve
# Out:
#       color-count  \
# 0             7.0
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 2843          NaN
# 2844          NaN
# 2845          NaN
# 2846          NaN
# 2847          NaN
#
#                                                                                                                                                goods-title-link--jump  \
# 0                                                                  SHEIN EZwear Women's Plus Size Sleeveless Jumpsuit With Inner Skirt And Pocket Shorts, Solid Color
# 1                                                                                          SHEIN EZwear Plus Size Water Wash Slanted Pocket Straight Leg Denim Shorts
# 2     SHEIN Slayr Plus Size Vacation & Elegance Slim-Fit Colorful Striped Crochet Semi-Sheer Sleeveless Vest-Style Mini Crochet Dress, Summer, Pride Month, Rainbow-E
# ...

# %%
curve.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2848 entries, 0 to 2847
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   color-count                  1370 non-null   float64
#  1   goods-title-link--jump       39 non-null     object
#  2   goods-title-link--jump href  39 non-null     object
#  3   rank-title                   532 non-null    object
#  4   rank-sub                     532 non-null    object
#  5   price                        2847 non-null   object
#  6   discount                     2768 non-null   object
#  7   selling_proposition          2293 non-null   object
#  8   goods-title-link             2808 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 200.4+ KB

# %%
curve.columns
# Out:
# Index(['color-count', 'goods-title-link--jump', 'goods-title-link--jump href',
#        'rank-title', 'rank-sub', 'price', 'discount', 'selling_proposition',
#        'goods-title-link'],
#       dtype='object')

# %% [markdown]
# ##7. us-shein-electronics-4395.csv

# %%
electronics = pd.read_csv("/content/drive/MyDrive/Data Science/3. Dirty E-Commerce Data [80,000+ Products]/data/us-shein-electronics-4395.csv")

# %%
electronics
# Out:
#                                                                                                                                                                                                                                                                 goods-title-link--jump  \
# 0                                                                                                                                                                                                                                              10pcs Random Color Data Cable Organizer
# 1                                                                                                                                                                                                                    3pcs Anti Glare Tempered Glass Front Film Phone Screen Protectors
# ...

# %%
electronics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4394 entries, 0 to 4393
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   goods-title-link--jump       38 non-null     object
#  1   goods-title-link--jump href  38 non-null     object
#  2   rank-title                   747 non-null    object
#  3   rank-sub                     747 non-null    object
#  4   price                        4394 non-null   object
#  5   discount                     1525 non-null   object
#  6   selling_proposition          3167 non-null   object
#  7   color-count                  1138 non-null   float64
#  8   goods-title-link             4356 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 309.1+ KB

# %%
electronics.columns
# Out:
# Index(['goods-title-link--jump', 'goods-title-link--jump href', 'rank-title',
#        'rank-sub', 'price', 'discount', 'selling_proposition', 'color-count',
#        'goods-title-link'],
#       dtype='object')

# %% [markdown]
# ##8. us-shein-home_and_kitchen-3719.csv

# %%
home_and_kitchen = pd.read_csv("/content/drive/MyDrive/Data Science/3. Dirty E-Commerce Data [80,000+ Products]/data/us-shein-home_and_kitchen-3719.csv")

# %%
home_and_kitchen
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               goods-title-link  \
# ...

# %%
home_and_kitchen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3719 entries, 0 to 3718
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   goods-title-link     3719 non-null   object
#  1   rank-title           1089 non-null   object
#  2   rank-sub             1089 non-null   object
#  3   price                3719 non-null   object
#  4   selling_proposition  2461 non-null   object
#  5   discount             1594 non-null   object
# dtypes: object(6)
# memory usage: 174.5+ KB

# %% [markdown]
# ##8. us-shein-home_textile-3883.csv

# %%
home_textile = pd.read_csv("/content/drive/MyDrive/Data Science/3. Dirty E-Commerce Data [80,000+ Products]/data/us-shein-home_textile-3883.csv")

# %%
home_textile
# Out:
#                                                                                                                                                                                                      goods-title-link--jump  \
# 0                                                                  1pc Multifunctional Bean Bag Sofa (Cover Only, Filling Not Included) Movable Foldable Furniture For Rental House Studio Apartment Living Room Sofa Cover
# 1                                                                                                                   1pc Tie Dye Pink Cozy Rabbit Fur Plush Blanket Luxury Fluffy Bedding Throw Soft And Comfortable Couches
# 2                                                                                                             1pc Large Foldable Food Cover Fly Proof Kitchen And Outdoor Camping Food Cover, Feast Insect Proof Food Cover
# ...

# %%
home_textile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3882 entries, 0 to 3881
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   goods-title-link--jump       39 non-null     object
#  1   goods-title-link--jump href  39 non-null     object
#  2   rank-title                   525 non-null    object
#  3   rank-sub                     525 non-null    object
#  4   price                        3882 non-null   object
#  5   color-count                  1177 non-null   float64
#  6   selling_proposition          2797 non-null   object
#  7   discount                     1469 non-null   object
#  8   goods-title-link             3843 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 273.1+ KB

# %%
home_textile.columns
# Out:
# Index(['goods-title-link--jump', 'goods-title-link--jump href', 'rank-title',
#        'rank-sub', 'price', 'color-count', 'selling_proposition', 'discount',
#        'goods-title-link'],
#       dtype='object')

# %% [markdown]
# ##9. us-shein-jewelry_and_accessories-3548.csv

# %%
jewelry_and_accessories = pd.read_csv("/content/drive/MyDrive/Data Science/3. Dirty E-Commerce Data [80,000+ Products]/data/us-shein-jewelry_and_accessories-3548.csv")

# %%
jewelry_and_accessories
# Out:
#                                                                                                                                                                                                                                                         goods-title-link--jump  \
# 0                                                                       Customized Personalized Heart-Shaped Lace Name Necklace - Perfect For Mother's Day, Valentine's Day, Birthday, Anniversary, Graduation, Christmas, Family And High-End Gift For Friends And Classmates
# 1                                                                                                                                                  24pcs/Set Simple Heart, Butterfly, Flower, Rhinestone & Faux Pearl Stud Earring Set For Women As A Gift For Dating/Vacation
# ...

# %%
jewelry_and_accessories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3547 entries, 0 to 3546
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   goods-title-link--jump       39 non-null     object
#  1   goods-title-link--jump href  39 non-null     object
#  2   rank-title                   716 non-null    object
#  3   rank-sub                     716 non-null    object
#  4   price                        3547 non-null   object
#  5   selling_proposition          2736 non-null   object
#  6   discount                     1926 non-null   object
#  7   goods-title-link             3508 non-null   object
# dtypes: object(8)
# memory usage: 221.8+ KB

# %%
jewelry_and_accessories.columns
# Out:
# Index(['goods-title-link--jump', 'goods-title-link--jump href', 'rank-title',
#        'rank-sub', 'price', 'selling_proposition', 'discount',
#        'goods-title-link'],
#       dtype='object')

# %% [markdown]
# ##10. us-shein-kids-4314.csv

# %%
kids = pd.read_csv("/content/drive/MyDrive/Data Science/3. Dirty E-Commerce Data [80,000+ Products]/data/us-shein-kids-4314.csv")

# %%
kids
# Out:
#       color-count  \
# 0             9.0
# 1            14.0
# 2             5.0
# 3             NaN
# 4             7.0
# ...           ...
# 4308          NaN
# 4309          NaN
# 4310          7.0
# 4311          NaN
# 4312         13.0
#
#                                                                          goods-title-link--jump  \
# 0     SHEIN Teen Girl Knitted Ribbed Pleated T-Shirt And Accordion Pocket Casual Long Pants Set
# 1                                           SHEIN Tween Girl Solid Tank Top & Knot Waist Shorts
# 2                                      SHEIN Young Girl Butterfly & Letter Graphic Tee & Shorts
# 3                                 SHEIN Teen Girl White Knitted Pintuck Fitted Bandeau Cami Top
# 4                  Young Girl Casual Loose Fit Simple Camouflage Print Multi-Pocket Denim Skirt
# ...                                                                                         ...
# ...

# %%
kids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4313 entries, 0 to 4312
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   color-count                  1366 non-null   float64
#  1   goods-title-link--jump       39 non-null     object
#  2   goods-title-link--jump href  39 non-null     object
#  3   rank-title                   783 non-null    object
#  4   rank-sub                     783 non-null    object
#  5   price                        4313 non-null   object
#  6   discount                     4262 non-null   object
#  7   selling_proposition          3435 non-null   object
#  8   goods-title-link             4274 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 303.4+ KB

# %%
kids.columns
# Out:
# Index(['color-count', 'goods-title-link--jump', 'goods-title-link--jump href',
#        'rank-title', 'rank-sub', 'price', 'discount', 'selling_proposition',
#        'goods-title-link'],
#       dtype='object')

# %% [markdown]
# ##11. us-shein-mens_clothes-1891.csv

# %%
mens_clothes = pd.read_csv("/content/drive/MyDrive/Data Science/3. Dirty E-Commerce Data [80,000+ Products]/data/us-shein-mens_clothes-1891.csv")

# %%
mens_clothes
# Out:
#       color-count  \
# 0            15.0
# 1             NaN
# 2             NaN
# 3            11.0
# 4             7.0
# ...           ...
# 1885          NaN
# 1886          NaN
# 1887          NaN
# 1888          NaN
# 1889          4.0
#
#                                                                               goods-title-link  \
# 0                                  Manfinity Homme Loose Fit Men's Solid Color Button Up Shirt
# 1                           Manfinity Joysei Men's Star Patterned Shorts With Drawstring Waist
# 2         Men's Summer Casual Short Sleeve T-Shirt With Slogan And Character Print, Round Neck
# 3         Manfinity Homme Men's Contrast Color Short Sleeve Polo Shirt With Decorative Details
# 4                                 Manfinity EMRG Loose Fit Men Plus Letter Printed Graphic Tee
# ...                                                                                        ...
# ...

# %%
mens_clothes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1890 entries, 0 to 1889
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   color-count          1141 non-null   float64
#  1   goods-title-link     1889 non-null   object
#  2   selling_proposition  1277 non-null   object
#  3   price                1889 non-null   object
#  4   discount             1860 non-null   object
#  5   rank-title           560 non-null    object
#  6   rank-sub             560 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 103.5+ KB

# %%
mens_clothes.columns
# Out:
# Index(['color-count', 'goods-title-link', 'selling_proposition', 'price',
#        'discount', 'rank-title', 'rank-sub'],
#       dtype='object')

# %% [markdown]
# ##12. us-shein-office_and_school_supplies-4233.csv

# %%
office_and_school_supplies = pd.read_csv("/content/drive/MyDrive/Data Science/3. Dirty E-Commerce Data [80,000+ Products]/data/us-shein-office_and_school_supplies-4233.csv")

# %%
office_and_school_supplies
# Out:
#                                                                                                                                                                                   goods-title-link--jump  \
# 0                                                      Colors Dual Tip Alcohol Based Art Markers, 262 Colors Permanent Marker Plus Colorless Blender, Micro-Tip Pens, Marker Bag For Kids Adult Coloring
# 1                                                                                                                                                1pc Expandable Large Capacity Canvas Simple Pencil Case
# 2     1pc Budget Planner - Monthly Finance Organizer With Expense Tracker Notebook To Manage Your Money Effectively, Undated Finance Planner/Account Book, Start Anytimem-A5(8.6x5.9 Inchs),100gsm Paper
# ...

# %%
office_and_school_supplies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4232 entries, 0 to 4231
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   goods-title-link--jump       39 non-null     object
#  1   goods-title-link--jump href  39 non-null     object
#  2   rank-title                   659 non-null    object
#  3   rank-sub                     659 non-null    object
#  4   price                        4232 non-null   object
#  5   discount                     1650 non-null   object
#  6   selling_proposition          2958 non-null   object
#  7   goods-title-link             4193 non-null   object
# dtypes: object(8)
# memory usage: 264.6+ KB

# %%
office_and_school_supplies.columns
# Out:
# Index(['goods-title-link--jump', 'goods-title-link--jump href', 'rank-title',
#        'rank-sub', 'price', 'discount', 'selling_proposition',
#        'goods-title-link'],
#       dtype='object')

# %% [markdown]
# ##13. us-shein-pet_supplies-4083.csv

# %%
pet_supplies = pd.read_csv("/content/drive/MyDrive/Data Science/3. Dirty E-Commerce Data [80,000+ Products]/data/us-shein-pet_supplies-4083.csv")

# %%
pet_supplies
# Out:
#                                                                                                                                             goods-title-link--jump  \
# 0                              Pet Shampoo Brush, Silicone Massage Rubber Bath Comb With Shampoo Dispenser, For Dogs And Cats Grooming Tool, Random Color Delivery
# 1                                                  1pc Fun Interactive Dog Toy - Cigar Shaped Plush Squeaky Chew Toy For Medium And Small Dogs Only (Pet Use Only)
# 2                                                                                                                             1pc Silicone Paw Detail Pet Placemat
# 3                                                                         1pc Pet Outdoor Sun Hat For Large/Medium/Small Dogs, Cats, And Kittens With Exposed Ears
# 4     Custom Dog Tags Pendant, Personalised Cat Dog Puppy Pet ID Name Pendants, Collar Tag Pendant Pet Accessories Bone Glitter Pendant, Perfect Gift For Your Pet
# ...

# %%
pet_supplies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4082 entries, 0 to 4081
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   goods-title-link--jump       40 non-null     object
#  1   goods-title-link--jump href  40 non-null     object
#  2   selling_proposition          2463 non-null   object
#  3   price                        4082 non-null   object
#  4   blackfridaybelts-bg src      2220 non-null   object
#  5   blackfridaybelts-content     2220 non-null   object
#  6   rank-title                   545 non-null    object
#  7   rank-sub                     545 non-null    object
#  8   discount                     2970 non-null   object
#  9   color-count                  481 non-null    float64
#  10  goods-title-link             4042 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 350.9+ KB

# %%
pet_supplies.columns
# Out:
# Index(['goods-title-link--jump', 'goods-title-link--jump href',
#        'selling_proposition', 'price', 'blackfridaybelts-bg src',
#        'blackfridaybelts-content', 'rank-title', 'rank-sub', 'discount',
#        'color-count', 'goods-title-link'],
#       dtype='object')

# %% [markdown]
# ##14. us-shein-shoes-4381.csv

# %%
shoes = pd.read_csv("/content/drive/MyDrive/Data Science/3. Dirty E-Commerce Data [80,000+ Products]/data/us-shein-shoes-4381.csv")

# %%
shoes
# Out:
#       color-count  \
# 0            18.0
# 1             8.0
# 2             4.0
# 3             5.0
# 4             NaN
# ...           ...
# 4375          NaN
# 4376          NaN
# 4377          NaN
# 4378          4.0
# 4379          NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    goods-title-link--jump  \
# ...

# %%
shoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4380 entries, 0 to 4379
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   color-count                  2180 non-null   float64
#  1   goods-title-link--jump       39 non-null     object
#  2   goods-title-link--jump href  39 non-null     object
#  3   rank-title                   1274 non-null   object
#  4   rank-sub                     1274 non-null   object
#  5   price                        4380 non-null   object
#  6   discount                     4249 non-null   object
#  7   selling_proposition          2799 non-null   object
#  8   goods-title-link             4341 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 308.1+ KB

# %%
shoes.columns
# Out:
# Index(['color-count', 'goods-title-link--jump', 'goods-title-link--jump href',
#        'rank-title', 'rank-sub', 'price', 'discount', 'selling_proposition',
#        'goods-title-link'],
#       dtype='object')

# %% [markdown]
# ##15. us-shein-sports_and_outdoors-3853.csv

# %%
sports_and_outdoors = pd.read_csv("/content/drive/MyDrive/Data Science/3. Dirty E-Commerce Data [80,000+ Products]/data/us-shein-sports_and_outdoors-3853.csv")

# %%
sports_and_outdoors
# Out:
#       color-count  \
# 0             5.0
# 1             NaN
# 2             8.0
# 3            13.0
# 4             NaN
# ...           ...
# 3847          NaN
# 3848          NaN
# 3849          NaN
# 3850          NaN
# 3851          NaN
#
#                                                                                    blackfridaybelts-bg src  \
# 0     https://img.ltwebstatic.com/images3_ccc/2023/12/11/10/1702282813131df089f4bfba6ce2678abd1c336bd0.png
# 1                                                                                                      NaN
# 2                                                                                                      NaN
# 3     https://img.ltwebstatic.com/images3_ccc/2023/12/11/10/1702282813131df089f4bfba6ce2678abd1c336bd0.png
# 4     https://img.ltwebstatic.com/images3_ccc/2023/12/11/10/1702282813131df089f4bfba6ce2678abd1c336bd0.png
# ...

# %%
sports_and_outdoors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3852 entries, 0 to 3851
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   color-count                  1215 non-null   float64
#  1   blackfridaybelts-bg src      1571 non-null   object
#  2   blackfridaybelts-content     1571 non-null   object
#  3   goods-title-link--jump       39 non-null     object
#  4   goods-title-link--jump href  39 non-null     object
#  5   rank-title                   1186 non-null   object
#  6   rank-sub                     1186 non-null   object
#  7   price                        3852 non-null   object
#  8   discount                     3225 non-null   object
#  9   selling_proposition          2493 non-null   object
#  10  goods-title-link             3813 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 331.2+ KB

# %%
sports_and_outdoors.columns
# Out:
# Index(['color-count', 'blackfridaybelts-bg src', 'blackfridaybelts-content',
#        'goods-title-link--jump', 'goods-title-link--jump href', 'rank-title',
#        'rank-sub', 'price', 'discount', 'selling_proposition',
#        'goods-title-link'],
#       dtype='object')

# %% [markdown]
# ##16. us-shein-swimwear-3761.csv

# %%
swimwear = pd.read_csv("/content/drive/MyDrive/Data Science/3. Dirty E-Commerce Data [80,000+ Products]/data/us-shein-swimwear-3761.csv")

# %%
swimwear
# Out:
#       color-count  \
# 0             6.0
# 1             6.0
# 2            14.0
# 3             NaN
# 4             4.0
# ...           ...
# 3755          NaN
# 3756          NaN
# 3757          NaN
# 3758          NaN
# 3759          NaN
#
#                                                                                              goods-title-link--jump  \
# 0                                       European And American Sexy V-neck Black And White Splice One-piece Swimsuit
# 1     SHEIN Swim Summer Beach Women's Floral Print Neck-Tie Halter Bikini Set With Random Flower Print For Vacation
# 2                                  SHEIN Swim Summer Beach Women's Floral Printed Halter Neck Swimsuit Set Carnival
# 3                       SHEIN Swim Women's Ditsy Floral Sexy Bikini Set For Beach Vacation, Two Pieces,Summer Beach
# 4               SHEIN Swim Summer Beach Women's Solid Color Halter Neck Bra & Swim Bottom Swimsuit Set Bathing Suit
# ...

# %%
swimwear.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3760 entries, 0 to 3759
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   color-count                  1906 non-null   float64
#  1   goods-title-link--jump       40 non-null     object
#  2   goods-title-link--jump href  40 non-null     object
#  3   price                        3760 non-null   object
#  4   rank-title                   594 non-null    object
#  5   rank-sub                     594 non-null    object
#  6   discount                     3541 non-null   object
#  7   goods-title-link             3720 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 235.1+ KB

# %%
swimwear.columns
# Out:
# Index(['color-count', 'goods-title-link--jump', 'goods-title-link--jump href',
#        'price', 'rank-title', 'rank-sub', 'discount', 'goods-title-link'],
#       dtype='object')

# %% [markdown]
# ##17. us-shein-tools_and_home_improvement-3903.csv

# %%
tools_and_home_improvement = pd.read_csv("/content/drive/MyDrive/Data Science/3. Dirty E-Commerce Data [80,000+ Products]/data/us-shein-tools_and_home_improvement-3903.csv")

# %%
tools_and_home_improvement
# Out:
#                                                                                                                                                                                                                                                                                                                                      goods-title-link--jump  \
# 0                                                                                                                                                                                                                          46pcs Car Repair Tool Kit: Ratchet Torque Wrench, Spanner, Screwdriver, Socket Set Combo - Perfect For Bicycle & Auto Repairing!
# ...

# %%
tools_and_home_improvement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3902 entries, 0 to 3901
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   goods-title-link--jump       38 non-null     object
#  1   goods-title-link--jump href  38 non-null     object
#  2   rank-title                   820 non-null    object
#  3   rank-sub                     820 non-null    object
#  4   price                        3902 non-null   object
#  5   selling_proposition          2339 non-null   object
#  6   discount                     1857 non-null   object
#  7   goods-title-link             3864 non-null   object
# dtypes: object(8)
# memory usage: 244.0+ KB

# %%
tools_and_home_improvement.columns
# Out:
# Index(['goods-title-link--jump', 'goods-title-link--jump href', 'rank-title',
#        'rank-sub', 'price', 'selling_proposition', 'discount',
#        'goods-title-link'],
#       dtype='object')

# %% [markdown]
# ##18. us-shein-toys_and_games-3577.csv

# %%
toys_and_games = pd.read_csv("/content/drive/MyDrive/Data Science/3. Dirty E-Commerce Data [80,000+ Products]/data/us-shein-toys_and_games-3577.csv")

# %%
toys_and_games
# Out:
#            rank-title                              rank-sub   price  \
# 0     #6 Best Sellers   in Kids Drawing & Painting Supplies   $2.90
# 1                 NaN                                   NaN   $2.40
# 2                 NaN                                   NaN   $3.80
# 3     #2 Best Sellers  in Musical Instruments & Accessories   $1.20
# 4                 NaN                                   NaN   $2.31
# ...               ...                                   ...     ...
# 3571              NaN                                   NaN  $45.32
# 3572              NaN                                   NaN  $79.27
# 3573              NaN                                   NaN   $3.00
# 3574              NaN                                   NaN   $6.00
# 3575              NaN                                   NaN   $1.44
#
#       selling_proposition discount  \
# 0                     NaN      NaN
# 1      600+ sold recently      NaN
# 2     1.2k+ sold recently      NaN
# ...

# %%
toys_and_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3576 entries, 0 to 3575
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   rank-title           583 non-null    object
#  1   rank-sub             583 non-null    object
#  2   price                3576 non-null   object
#  3   selling_proposition  2303 non-null   object
#  4   discount             1510 non-null   object
#  5   goods-title-link     3564 non-null   object
# dtypes: object(6)
# memory usage: 167.8+ KB

# %%
toys_and_games.columns
# Out:
# Index(['rank-title', 'rank-sub', 'price', 'selling_proposition', 'discount',
#        'goods-title-link'],
#       dtype='object')

# %% [markdown]
# ##19. us-shein-underwear_and_sleepwear-4019.csv

# %%
underwear_and_sleepwear = pd.read_csv("/content/drive/MyDrive/Data Science/3. Dirty E-Commerce Data [80,000+ Products]/data/us-shein-underwear_and_sleepwear-4019.csv")

# %%
underwear_and_sleepwear
# Out:
#                                                                              goods-title-link--jump  \
# 0                        Pocket Letter Embroidery Imitation Silk Collar Shirt And Shorts Pajama Set
# 1                                                                          5pcs Solid Underwire Bra
# 2          Cherry Printed Sweet Sleepwear Set With Lapel Button Up Top And Bowknot Shorts For Women
# 3     Plus Size 'GOODNIGHT' Pattern White Short Sleeve T-Shirt And Black & White Checked Shorts Set
# 4                                         12pcs Solid Color Seamless Comfortable Triangle Underwear
# ...                                                                                             ...
# 4013                                                                                            NaN
# 4014                                                                                            NaN
# ...

# %%
underwear_and_sleepwear.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4018 entries, 0 to 4017
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   goods-title-link--jump       39 non-null     object
#  1   goods-title-link--jump href  39 non-null     object
#  2   selling_proposition          2746 non-null   object
#  3   price                        4018 non-null   object
#  4   discount                     3051 non-null   object
#  5   rank-title                   1134 non-null   object
#  6   rank-sub                     1134 non-null   object
#  7   color-count                  1265 non-null   float64
#  8   goods-title-link             3979 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 282.6+ KB

# %%
underwear_and_sleepwear.columns
# Out:
# Index(['goods-title-link--jump', 'goods-title-link--jump href',
#        'selling_proposition', 'price', 'discount', 'rank-title', 'rank-sub',
#        'color-count', 'goods-title-link'],
#       dtype='object')

# %% [markdown]
# ##20. us-shein-womens_clothing-4620.csv

# %%
womens_clothing = pd.read_csv("/content/drive/MyDrive/Data Science/3. Dirty E-Commerce Data [80,000+ Products]/data/us-shein-womens_clothing-4620.csv")

# %%
womens_clothing
# Out:
#                                                                               product-locatelabels-img src  \
# 0     https://img.ltwebstatic.com/images3_pi/2024/02/28/ec/1709121330c7d4754faa4ce295ce8a49c297ed271b.webp
# 1                                                                                                      NaN
# 2                                                                                                      NaN
# 3              https://img.shein.com/images3/2024/04/30/0e/17144632041840186e117a2c12e0f7ec0daab7f390.webp
# 4     https://img.ltwebstatic.com/images3_pi/2024/02/28/ec/1709121330c7d4754faa4ce295ce8a49c297ed271b.webp
# ...                                                                                                    ...
# 4614                                                                                                   NaN
# 4615                                                                                                   NaN
# ...

# %%
womens_clothing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4619 entries, 0 to 4618
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   product-locatelabels-img src  3622 non-null   object
#  1   color-count                   2415 non-null   float64
#  2   goods-title-link              4619 non-null   object
#  3   rank-title                    1056 non-null   object
#  4   rank-sub                      1056 non-null   object
#  5   price                         4619 non-null   object
#  6   discount                      2752 non-null   object
#  7   selling_proposition           3452 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 288.8+ KB

# %%
womens_clothing.columns
# Out:
# Index(['product-locatelabels-img src', 'color-count', 'goods-title-link',
#        'rank-title', 'rank-sub', 'price', 'discount', 'selling_proposition'],
#       dtype='object')
